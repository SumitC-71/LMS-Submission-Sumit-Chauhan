# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder\
                    .appName('Practice-Session')\
                    .getOrCreate()

# %%
table = [
    ('john',25),
    ('snow',27)
]

df = spark.createDataFrame(table, ['name','age'])

# %%
df.show()

df.count()
# Out:
# +----+---+
# |name|age|
# +----+---+
# |john| 25|
# |snow| 27|
# +----+---+
# 2

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 spark.memory.fraction
#
# AttributeError: 'SparkSession' object has no attribute 'memory'
