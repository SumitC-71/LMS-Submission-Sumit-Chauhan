# %% [markdown]
# ## Edge cases in python

# %%
x=  0*1e1000
x == x  # this is because x currently is NaN and NaN == NaN gives false
# Out:
# False

# %%
0*1e1000
# Out:
# nan

# %%
float('nan')
# Out:
# nan

# %%
from decimal import Decimal; Decimal('nan')
Decimal('NaN')
# Out:
# Decimal('NaN')

# %%
x = ...
a = ...
b = ...
c = ...
max(x) < max(x[a:b:c])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 b = ...
#       4 c = ...
# ----> 5 max(x) < max(x[a:b:c])
#
# TypeError: 'ellipsis' object is not iterable

# %%
print(0 < 1)

print({0} < {1})

print({1,0})

print({0,1})

print({0} < {0,1})
print({0} < {1,0})
# Out:
# True
# False
# {0, 1}
# {0, 1}
# True
# True

# %%
x = [1,2]
y = [3,4]
print(any(x) and not any(x+y))
# Out:
# False

# %%
x = 'foobar'
y = ''
print("len(x)", len(x))
print("'foobar'.count('')",'foobar'.count(''))
# Out:
# len(x) 6
# 'foobar'.count('') 7

# %%
print('hello world')
# Out:
# hello world

# %%
dic = {'name':'sumit','ab':'ab'}
for key in dic:
    print(key)
# Out:
# name
# ab

# %%
'''
covered some edge cases
given online quizes 
frozen sets
double underscore methods for operator overloading


'''
