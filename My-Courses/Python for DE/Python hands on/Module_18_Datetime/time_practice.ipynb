# %%
'''
epoch that begins at 00:00:00, 1st Jan 1970
'''

import time

# %%
print('time()',time.time())
print('ctime()',time.ctime(time.time()))

# time.sleep(2) # excepts seconds
# Out:
# time() 1773134112.0459435
# ctime() Tue Mar 10 14:45:12 2026

# %%
print('localtime()',a:=time.localtime())
# final attribute: tm_isdst -> day light saving time says 1 if summer 0 otherwise -1 if unkown
# Out:
# localtime() time.struct_time(tm_year=2026, tm_mon=3, tm_mday=10, tm_hour=14, tm_min=45, tm_sec=24, tm_wday=1, tm_yday=69, tm_isdst=0)

# %%
b=time.mktime(a) # total seconds from epoch till now

# %%
print('mktime(a)',b) # total seconds passed since epoch
# Out:
# mktime(a) 1773134124.0

# %%
c = time.asctime(a)
print('asctime()' ,c)
# Out:
# asctime() Tue Mar 10 14:45:24 2026

# %%
# strftime

a = time.localtime()
print(a)

x=time.strftime('%m/%d/%Y')

print(x)
# Out:
# time.struct_time(tm_year=2026, tm_mon=3, tm_mday=10, tm_hour=14, tm_min=46, tm_sec=0, tm_wday=1, tm_yday=69, tm_isdst=0)
# 03/10/2026

# %%
y = '10 March 2026'
s = time.strptime(y,'%d %B %Y')

print(s)
# Out:
# time.struct_time(tm_year=2026, tm_mon=3, tm_mday=10, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=69, tm_isdst=-1)
