# %%
import pandas as pd
import numpy as np

# %%
np.random.randn(10,4)
# Out:
# array([[ 1.73119658, -0.55648395, -0.56196541, -3.19151102],
#        [ 1.34590272, -1.38757137, -0.60174005, -1.28584198],
#        [-0.25848915, -1.06832537, -0.95988102, -0.68666078],
#        [ 0.44725215, -0.41185177, -1.77068004,  0.40472109],
#        [-0.08012619,  0.24308315, -1.00620143,  0.10127777],
#        [-0.14315719,  1.60685   ,  0.96520794, -0.00796431],
#        [ 0.21101495, -0.10855072,  1.21183253,  1.6311891 ],
#        [ 1.24516901, -0.89976544,  0.89209405,  1.20826409],
#        [-0.61547356, -0.27010371, -1.71108529, -0.04806973],
#        [-1.14121038, -1.27896058,  0.22438896, -0.80133127]])

# %%
s = pd.Series([1,2,3,5,6,np.nan,8,9])
# s = pd.Series(1221,list(range(10)),dtype='Float32')
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    5.0
# 4    6.0
# 5    NaN
# 6    8.0
# 7    9.0
# dtype: float64

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    5.0
# 4    6.0
# 5    NaN
# 6    8.0
# 7    9.0
# dtype: float64

# %%
d = pd.date_range('20200301',periods=10)

# %%
d
# Out:
# DatetimeIndex(['2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#                '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08',
#                '2020-03-09', '2020-03-10'],
#               dtype='datetime64[us]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(10,4), index=d, columns=['A','B','C','D'])

# %%
df
# Out:
#                    A         B         C         D
# 2020-03-01  2.002350 -1.226832 -0.076228  0.651176
# 2020-03-02 -0.018216 -0.011510  0.489748 -1.090520
# 2020-03-03 -2.414414  1.160040 -0.087658 -0.777813
# 2020-03-04  0.184356 -1.681491  0.210106 -0.371462
# 2020-03-05  0.144959 -0.268006  1.022629  0.144729
# 2020-03-06 -0.836077  1.873663  0.757519 -1.198493
# 2020-03-07 -0.854285  0.607433  1.690442  0.113853
# 2020-03-08 -0.816667  0.084579  0.466812 -0.795922
# 2020-03-09  1.022134  0.702633 -0.669452  1.384054
# 2020-03-10  0.339508  0.813404 -0.821435 -0.229919

# %%
df1 = pd.DataFrame({
                    'A':[1,2,3,4],
                    'B': pd.Timestamp('20200301'),
                    'C': pd.Series(1,index=list(range(4)),dtype='Float32'),
                    'D': np.array([5]*4,dtype='int32'),
                    'E': pd.Categorical(['True','False','True','False']),
                    'F': 'Practice'
                })

# %%
df1
# Out:
#    A          B    C  D      E         F
# 0  1 2020-03-01  1.0  5   True  Practice
# 1  2 2020-03-01  1.0  5  False  Practice
# 2  3 2020-03-01  1.0  5   True  Practice
# 3  4 2020-03-01  1.0  5  False  Practice

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %%
# How to view data
df.head(3)  # default 5
# Out:
#                    A         B         C         D
# 2020-03-01  2.002350 -1.226832 -0.076228  0.651176
# 2020-03-02 -0.018216 -0.011510  0.489748 -1.090520
# 2020-03-03 -2.414414  1.160040 -0.087658 -0.777813

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2020-03-06 -0.836077  1.873663  0.757519 -1.198493
# 2020-03-07 -0.854285  0.607433  1.690442  0.113853
# 2020-03-08 -0.816667  0.084579  0.466812 -0.795922
# 2020-03-09  1.022134  0.702633 -0.669452  1.384054
# 2020-03-10  0.339508  0.813404 -0.821435 -0.229919

# %%
df.index
# Out:
# DatetimeIndex(['2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#                '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08',
#                '2020-03-09', '2020-03-10'],
#               dtype='datetime64[us]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='str')

# %%
# df.to_numpy() is very fast and does not require copying data to np array
df.to_numpy()
# Out:
# array([[ 2.00235035, -1.22683199, -0.07622758,  0.65117629],
#        [-0.0182158 , -0.01150963,  0.48974773, -1.09051999],
#        [-2.41441352,  1.16004005, -0.08765832, -0.77781256],
#        [ 0.18435583, -1.68149099,  0.21010598, -0.3714623 ],
#        [ 0.14495933, -0.26800633,  1.02262946,  0.14472864],
#        [-0.83607739,  1.8736625 ,  0.75751936, -1.19849286],
#        [-0.85428468,  0.60743283,  1.69044229,  0.11385277],
#        [-0.8166672 ,  0.0845795 ,  0.46681245, -0.79592197],
#        [ 1.02213384,  0.70263309, -0.66945161,  1.38405407],
#        [ 0.33950775,  0.81340427, -0.821435  , -0.22991879]])

# %%
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.124635   0.205391   0.298248  -0.217032
# std     1.201600   1.073436   0.762015   0.813597
# min    -2.414414  -1.681491  -0.821435  -1.198493
# 25%    -0.831225  -0.203882  -0.084801  -0.791395
# 50%     0.063372   0.346006   0.338459  -0.300691
# 75%     0.300720   0.785711   0.690576   0.137010
# max     2.002350   1.873663   1.690442   1.384054

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2020-03-01  0.651176 -0.076228 -1.226832  2.002350
# 2020-03-02 -1.090520  0.489748 -0.011510 -0.018216
# 2020-03-03 -0.777813 -0.087658  1.160040 -2.414414
# 2020-03-04 -0.371462  0.210106 -1.681491  0.184356
# 2020-03-05  0.144729  1.022629 -0.268006  0.144959
# 2020-03-06 -1.198493  0.757519  1.873663 -0.836077
# 2020-03-07  0.113853  1.690442  0.607433 -0.854285
# 2020-03-08 -0.795922  0.466812  0.084579 -0.816667
# 2020-03-09  1.384054 -0.669452  0.702633  1.022134
# 2020-03-10 -0.229919 -0.821435  0.813404  0.339508

# %%
df.sort_values(by='C',ascending=True)
# Out:
#                    A         B         C         D
# 2020-03-10  0.339508  0.813404 -0.821435 -0.229919
# 2020-03-09  1.022134  0.702633 -0.669452  1.384054
# 2020-03-03 -2.414414  1.160040 -0.087658 -0.777813
# 2020-03-01  2.002350 -1.226832 -0.076228  0.651176
# 2020-03-04  0.184356 -1.681491  0.210106 -0.371462
# 2020-03-08 -0.816667  0.084579  0.466812 -0.795922
# 2020-03-02 -0.018216 -0.011510  0.489748 -1.090520
# 2020-03-06 -0.836077  1.873663  0.757519 -1.198493
# 2020-03-05  0.144959 -0.268006  1.022629  0.144729
# 2020-03-07 -0.854285  0.607433  1.690442  0.113853

# %%
df['C']
# Out:
# 2020-03-01   -0.076228
# 2020-03-02    0.489748
# 2020-03-03   -0.087658
# 2020-03-04    0.210106
# 2020-03-05    1.022629
# 2020-03-06    0.757519
# 2020-03-07    1.690442
# 2020-03-08    0.466812
# 2020-03-09   -0.669452
# 2020-03-10   -0.821435
# Freq: D, Name: C, dtype: float64

# %%
# slicing row
df[0:3]   # 3 exlusive
# Out:
#                    A         B         C         D
# 2020-03-01  2.002350 -1.226832 -0.076228  0.651176
# 2020-03-02 -0.018216 -0.011510  0.489748 -1.090520
# 2020-03-03 -2.414414  1.160040 -0.087658 -0.777813

# %%
df.loc[d[0]]
# Out:
# A    2.002350
# B   -1.226832
# C   -0.076228
# D    0.651176
# Name: 2020-03-01 00:00:00, dtype: float64

# %%
df.loc['20200301':'20200304',['A', 'C']]
# Out:
#                    A         C
# 2020-03-01  2.002350 -0.076228
# 2020-03-02 -0.018216  0.489748
# 2020-03-03 -2.414414 -0.087658
# 2020-03-04  0.184356  0.210106

# %%
df.loc[d[0],['D','C']]
# takes index values and column names
# Out:
# D    0.651176
# C   -0.076228
# Name: 2020-03-01 00:00:00, dtype: float64

# %%
df.at[d[0],'C']
# used to return scalar values
# Out:
# np.float64(-0.07622757744786228)

# %%
df.iloc[3,[1,3]]   
# uses 0-based indexing
# takes indexes(not index values) of rows and indexes of columns
# Out:
# B   -1.681491
# D   -0.371462
# Name: 2020-03-04 00:00:00, dtype: float64

# %%
df[df['A'] > 0]
# Out:
#                    A         B         C         D
# 2020-03-01  2.002350 -1.226832 -0.076228  0.651176
# 2020-03-04  0.184356 -1.681491  0.210106 -0.371462
# 2020-03-05  0.144959 -0.268006  1.022629  0.144729
# 2020-03-09  1.022134  0.702633 -0.669452  1.384054
# 2020-03-10  0.339508  0.813404 -0.821435 -0.229919

# %%
# for inserting a new column we can create a series
# this series can be generated based on other rows, postitions, indexes values etc. and order is aligned

# %%
# Handling Missing data
# first you need to do reindex

df2 = df.reindex(index=d[0:4], columns=list(df.columns) + ['E'])

# %%
df2.loc[d[0]:d[1],'E']=1

# %%
df2
# Out:
#                    A         B         C         D    E
# 2020-03-01  2.002350 -1.226832 -0.076228  0.651176  1.0
# 2020-03-02 -0.018216 -0.011510  0.489748 -1.090520  1.0
# 2020-03-03 -2.414414  1.160040 -0.087658 -0.777813  NaN
# 2020-03-04  0.184356 -1.681491  0.210106 -0.371462  NaN

# %%
df2.isnull()
# Out:
#                 A      B      C      D      E
# 2020-03-01  False  False  False  False  False
# 2020-03-02  False  False  False  False  False
# 2020-03-03  False  False  False  False   True
# 2020-03-04  False  False  False  False   True

# %%
df2.fillna(value=2)
# Out:
#                    A         B         C         D    E
# 2020-03-01  2.002350 -1.226832 -0.076228  0.651176  1.0
# 2020-03-02 -0.018216 -0.011510  0.489748 -1.090520  1.0
# 2020-03-03 -2.414414  1.160040 -0.087658 -0.777813  2.0
# 2020-03-04  0.184356 -1.681491  0.210106 -0.371462  2.0

# %%
pd.isna(df2)   # same as df2.innull()
# Out:
#                 A      B      C      D      E
# 2020-03-01  False  False  False  False  False
# 2020-03-02  False  False  False  False  False
# 2020-03-03  False  False  False  False   True
# 2020-03-04  False  False  False  False   True

# %%
# pandas operations
# descriptive stastic operations
# applying functions to data
# string processing
# histogramming

# %%
df.mean(1)
# Out:
# C:\Users\sumit.chauhan\AppData\Local\Temp\ipykernel_22276\3808537418.py:1: Pandas4Warning: Starting with pandas version 4.0 all arguments of mean will be keyword-only.
#   df.mean(1)
# 2020-03-01    0.337617
# 2020-03-02   -0.157624
# 2020-03-03   -0.529961
# 2020-03-04   -0.414623
# 2020-03-05    0.261078
# 2020-03-06    0.149153
# 2020-03-07    0.389361
# 2020-03-08   -0.265299
# 2020-03-09    0.609842
# 2020-03-10    0.025390
# Freq: D, dtype: float64

# %%
s = pd.Series([1,2,3,np.nan,4,5,6,7,8,9], index=d).shift(-2)   # 2 = shifting down, -2 = shifting up

# %%
s
# Out:
# 2020-03-01    3.0
# 2020-03-02    NaN
# 2020-03-03    4.0
# 2020-03-04    5.0
# 2020-03-05    6.0
# 2020-03-06    7.0
# 2020-03-07    8.0
# 2020-03-08    9.0
# 2020-03-09    NaN
# 2020-03-10    NaN
# Freq: D, dtype: float64

# %%
df.sub(s,axis='index')
# Out:
#                    A         B         C         D
# 2020-03-01 -0.997650 -4.226832 -3.076228 -2.348824
# 2020-03-02       NaN       NaN       NaN       NaN
# 2020-03-03 -6.414414 -2.839960 -4.087658 -4.777813
# 2020-03-04 -4.815644 -6.681491 -4.789894 -5.371462
# 2020-03-05 -5.855041 -6.268006 -4.977371 -5.855271
# 2020-03-06 -7.836077 -5.126337 -6.242481 -8.198493
# 2020-03-07 -8.854285 -7.392567 -6.309558 -7.886147
# 2020-03-08 -9.816667 -8.915421 -8.533188 -9.795922
# 2020-03-09       NaN       NaN       NaN       NaN
# 2020-03-10       NaN       NaN       NaN       NaN

# %%
df.apply(np.cumsum,axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\sumit.chauhan\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\_core\fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      53 try:
# ---> 54     return bound(*args, **kwds)
#      55 except TypeError:
#      56     # A TypeError occurs if the object does have such a method in its
#      57     # class, but its signature is not identical to that of NumPy's. This
#    (...)     61     # Call _wrapit from within the except clause to ensure a potential
#      62     # exception has a traceback chain.
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
df.apply(lambda x: x.max() - x.min(),axis=1)

# axis 1 means group by rows
# axis 0 means group by columns
# Out:
# 2020-03-01    3.229182
# 2020-03-02    1.580268
# 2020-03-03    3.574454
# 2020-03-04    1.891597
# 2020-03-05    1.290636
# 2020-03-06    3.072155
# 2020-03-07    2.544727
# 2020-03-08    1.283480
# 2020-03-09    2.053506
# 2020-03-10    1.634839
# Freq: D, dtype: float64

# %%
s.value_counts()

# histogramming
# Out:
# 3.0    1
# 4.0    1
# 5.0    1
# 6.0    1
# 7.0    1
# 8.0    1
# 9.0    1
# Name: count, dtype: int64

# %%
# string methods on series

s = pd.Series(['inter','python','hero',np.nan,'zero','hello'])

# %%
s.str.upper()
# Out:
# 0     INTER
# 1    PYTHON
# 2      HERO
# 3       NaN
# 4      ZERO
# 5     HELLO
# dtype: str

# %%
# merging for concating two dataframes

df = pd.DataFrame(np.random.randn(10,4))

# %%
df2 = [df[:3], df[3:7], df[7:]]

# %%
df2
# Out:
# [          0         1         2         3
#  0  1.131169 -0.433381  0.539709  0.462182
#  1  0.759439 -1.203624  0.067746  0.451664
#  2 -1.183072 -0.280197  1.689065  0.902261,
#            0         1         2         3
#  3  0.737812 -2.225890 -0.329045  1.570331
#  4 -0.528527 -0.814152 -0.479685 -0.588844
#  5  0.795148 -0.821238  0.784591 -0.971009
#  6 -2.306343 -1.450235 -1.108438 -2.201019,
#            0         1         2         3
#  7 -0.130339 -0.347266 -0.555876 -0.149297
#  8  0.273789  0.411233  0.135797 -2.419828
#  9 -0.360123 -1.900526  0.082377 -0.482043]

# %%
pd.concat(df2)
# Out:
#           0         1         2         3
# 0  1.131169 -0.433381  0.539709  0.462182
# 1  0.759439 -1.203624  0.067746  0.451664
# 2 -1.183072 -0.280197  1.689065  0.902261
# 3  0.737812 -2.225890 -0.329045  1.570331
# 4 -0.528527 -0.814152 -0.479685 -0.588844
# 5  0.795148 -0.821238  0.784591 -0.971009
# 6 -2.306343 -1.450235 -1.108438 -2.201019
# 7 -0.130339 -0.347266 -0.555876 -0.149297
# 8  0.273789  0.411233  0.135797 -2.419828
# 9 -0.360123 -1.900526  0.082377 -0.482043

# %%
# join functions

# left join

left = pd.DataFrame({'A': [1,2], 'B': [3,4]})
left
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
right = pd.DataFrame({'A': [3,2], 'D': [4,5]})
right
# Out:
#    A  D
# 0  3  4
# 1  2  5

# %%
pd.merge(left, right, on='A')
# Out:
#    A  B  D
# 0  2  4  5

# %%
# grouping data in data frame
# first make groups 
# apply some function

# %%
df
# Out:
#           0         1         2         3
# 0  1.131169 -0.433381  0.539709  0.462182
# 1  0.759439 -1.203624  0.067746  0.451664
# 2 -1.183072 -0.280197  1.689065  0.902261
# 3  0.737812 -2.225890 -0.329045  1.570331
# 4 -0.528527 -0.814152 -0.479685 -0.588844
# 5  0.795148 -0.821238  0.784591 -0.971009
# 6 -2.306343 -1.450235 -1.108438 -2.201019
# 7 -0.130339 -0.347266 -0.555876 -0.149297
# 8  0.273789  0.411233  0.135797 -2.419828
# 9 -0.360123 -1.900526  0.082377 -0.482043

# %%
df.groupby(2).sum()
# Out:
#                   0         1         3
# 2
# -1.108438 -2.306343 -1.450235 -2.201019
# -0.555876 -0.130339 -0.347266 -0.149297
# -0.479685 -0.528527 -0.814152 -0.588844
# -0.329045  0.737812 -2.225890  1.570331
#  0.067746  0.759439 -1.203624  0.451664
#  0.082377 -0.360123 -1.900526 -0.482043
#  0.135797  0.273789  0.411233 -2.419828
#  0.539709  1.131169 -0.433381  0.462182
#  0.784591  0.795148 -0.821238 -0.971009
#  1.689065 -1.183072 -0.280197  0.902261

# %%
df.groupby([2,3]).sum()
# grouped index with 2nd and 3rd column
# Out:
#                             0         1
# 2         3
# -1.108438 -2.201019 -2.306343 -1.450235
# -0.555876 -0.149297 -0.130339 -0.347266
# -0.479685 -0.588844 -0.528527 -0.814152
# -0.329045  1.570331  0.737812 -2.225890
#  0.067746  0.451664  0.759439 -1.203624
#  0.082377 -0.482043 -0.360123 -1.900526
#  0.135797 -2.419828  0.273789  0.411233
#  0.539709  0.462182  1.131169 -0.433381
#  0.784591 -0.971009  0.795148 -0.821238
#  1.689065  0.902261 -1.183072 -0.280197

# %%
# reshaping
# stack and pivot table

my_tuple = list(zip(*[[1,2,3,4,5,17,18,19], [11,12,13,6,7,8,9,10]]))

# %%
index = pd.MultiIndex.from_tuples(my_tuple, names= ['First', 'Second'])

# %%
df = pd.DataFrame(np.random.randn(8,2), index= index, columns= ['A','B'])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# First Second
# 1     11     -1.205311 -0.613667
# 2     12      1.174766 -0.544351
# 3     13     -0.452439  0.163244
# 4     6       2.769556  0.671145

# %%
a=df2.stack()

# %%
a
# Out:
# First  Second
# 1      11      A   -1.205311
#                B   -0.613667
# 2      12      A    1.174766
#                B   -0.544351
# 3      13      A   -0.452439
#                B    0.163244
# 4      6       A    2.769556
#                B    0.671145
# dtype: float64

# %%
a.unstack()
# Out:
#                      A         B
# First Second
# 1     11     -1.205311 -0.613667
# 2     12      1.174766 -0.544351
# 3     13     -0.452439  0.163244
# 4     6       2.769556  0.671145

# %%
df = pd.DataFrame({
                    'A': ['a','b','c','d'] * 3,
                   'B': ['A','B','C'] * 4,
                   'C': ['P','P','P','Q','Q','Q'] * 2,
                   'D': np.random.randn(12),
                   'E': np.random.randn(12)
                })

# %%
df
# Out:
#     A  B  C         D         E
# 0   a  A  P -0.510205 -0.309354
# 1   b  B  P  0.807017  0.110124
# 2   c  C  P -0.894343 -0.626413
# 3   d  A  Q  0.565977 -1.557089
# 4   a  B  Q  0.394244  1.508461
# 5   b  C  Q  0.189145 -0.849798
# 6   c  A  P  0.256025 -0.395666
# 7   d  B  P -0.810087 -2.083727
# 8   a  C  P -1.594272 -0.061151
# 9   b  A  Q  0.709392 -1.745219
# 10  c  B  Q  0.377130  0.052134
# 11  d  C  Q -0.782456  0.276219

# %%
# pivot tables
pd.pivot_table(df, values=['D','E'], index= ['B','C'], columns=['A'])
# Out:
#             D                                       E                      \
# A           a         b         c         d         a         b         c
# B C
# A P -0.510205       NaN  0.256025       NaN -0.309354       NaN -0.395666
#   Q       NaN  0.709392       NaN  0.565977       NaN -1.745219       NaN
# B P       NaN  0.807017       NaN -0.810087       NaN  0.110124       NaN
#   Q  0.394244       NaN  0.377130       NaN  1.508461       NaN  0.052134
# C P -1.594272       NaN -0.894343       NaN -0.061151       NaN -0.626413
#   Q       NaN  0.189145       NaN -0.782456       NaN -0.849798       NaN
#
#
# A           d
# B C
# A P       NaN
#   Q -1.557089
# B P -2.083727
#   Q       NaN
# C P       NaN
#   Q  0.276219

# %%
# Time series & categorical Data

dates = pd.date_range('20200301', periods=100, freq='s')

# %%
# categoricals

df = pd.DataFrame({
        'id': [1,2,3,4,5,6],
        'grade': ['a', 'b', 'c', 'b', 'a', 'e']
})

# %%
df
# Out:
#    id grade
# 0   1     a
# 1   2     b
# 2   3     c
# 3   4     b
# 4   5     a
# 5   6     e

# %%
df['Grade'] =  df['grade'].astype('category')

# %%
df
# Out:
#    id grade Grade
# 0   1     a     a
# 1   2     b     b
# 2   3     c     c
# 3   4     b     b
# 4   5     a     a
# 5   6     e     e

# %%
df['Grade'] = df['Grade'].cat.set_categories(
    ['good', 'very bad', 'very good', 'excellent']
)

# %%
df
# Out:
#    id grade Grade
# 0   1     a   NaN
# 1   2     b   NaN
# 2   3     c   NaN
# 3   4     b   NaN
# 4   5     a   NaN
# 5   6     e   NaN

# %%
# ploting

import matplotlib.pyplot as plt

# %%
plt.close('all')

# %%
ts = pd.Series(np.random.randn(500), index = pd.date_range('1/2/2020', periods=500))

# %%
ts = ts.cumsum()

# %%
ts.plot()
# Out:
# <Axes: >

# %%
# reading writing from files

# %%
ts.to_csv('ts.csv')

# %%
# ts.read_csv('filepath')
